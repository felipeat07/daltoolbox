# %%
# DAL Library
# version 1.0.24

source("https://raw.githubusercontent.com/cefet-rj-dal/dal/main/examples/jupyter_daltoolbox.R")

#loading DAL
load_daltoolbox() 
loadlibrary("ggplot2")
loadlibrary("dplyr")
loadlibrary("reshape")
loadlibrary("RColorBrewer")

# %%
#color palette
colors <- brewer.pal(4, 'Set1')

# setting the font size for all charts
font <- theme(text = element_text(size=16))

# %% [markdown]
# ## Examples using data distribution
# The following examples use random variables so that different data distribution can be better viewed.

# %%
# example4: dataset to be plotted  
example <- data.frame(exponential = rexp(100000, rate = 1), 
                     uniform = runif(100000, min = 2.5, max = 3.5), 
                     normal = rnorm(100000, mean=5))
head(example)
# Out:
#   exponential uniform  normal
# 1 1.33410278  3.357871 4.272337
# 2 0.73927688  3.006844 5.528426
# 3 2.21492423  3.111345 4.303191
# 4 0.04786372  3.010757 4.803592
# 5 1.77333760  2.939920 5.435216
# 6 0.27751160  2.745888 4.399750

# %% [markdown]
# ## Density plot
#
# Computes and draws kernel density estimate, which is a smoothed version of the histogram. This is a useful alternative to the histogram for continuous data that comes from an underlying smooth distribution.
#
# More information: ?geom_density (R documentation)

# %%
options(repr.plot.width=5, repr.plot.height=4)
grf <- plot.density(example, colors=colors[1:3]) + font
plot(grf)
# Out:
# Using  as id variables
# plot without title

# %% [markdown]
# ## Arrangement of graphs
#
# Function $grid.arrange$ is used to position previously computed charts

# %%
grfe <- plot.density(example %>% select(exponential), 
                     label_x = "exponential", color=colors[1]) + font  
grfu <- plot.density(example %>% select(uniform), 
                     label_x = "uniform", color=colors[2]) + font  
grfn <- plot.density(example %>% select(normal), 
                     label_x = "normal", color=colors[3]) + font
# Out:
# Using  as id variables
#
# Using  as id variables
#
# Using  as id variables

# %%
loadlibrary("gridExtra") 
options(repr.plot.width=15, repr.plot.height=4)
grid.arrange(grfe, grfu, grfn, ncol=3)
# Out:
# plot without title
